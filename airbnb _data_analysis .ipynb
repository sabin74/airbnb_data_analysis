# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv(r"listings.csv")
df.head()
# Out:
#         id                                              name   host_id  \
# 0  2992450                        Luxury 2 bedroom apartment   4621559
# 1  3820211         Restored Precinct in Center Sq. w/Parking  19648678
# 2  5651579        Large studio apt  by Capital Center & ESP@  29288920
# 3  6623339  Center Sq. Loft in Converted Precinct w/ Parking  19648678
# 4  9005989    Studio in The heart of Center SQ, in Albany NY  17766924
#
#   host_name  neighbourhood_group neighbourhood  latitude  longitude  \
# 0   Kenneth                  NaN    THIRD WARD  42.65789  -73.75370
# 1     Terra                  NaN    SIXTH WARD  42.65222  -73.76724
# 2     Gregg                  NaN   SECOND WARD  42.64615  -73.75966
# 3     Terra                  NaN    SIXTH WARD  42.65222  -73.76724
# 4     Sugey                  NaN    SIXTH WARD  42.65559  -73.76506
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt   70.0              28                  9  2022-08-17
# 1  Entire home/apt  102.0               2                308  2025-03-29
# 2  Entire home/apt   75.0               2                371  2025-02-16
# 3  Entire home/apt   96.0               2                331  2025-02-09
# 4  Entire home/apt   88.0               1                617  2025-04-13
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.07                               1                32
# 1               2.36                               4               334
# 2               3.05                               2                 6
# 3               2.74                               4               305
# 4               5.80                               1               167
#
#    number_of_reviews_ltm  license
# 0                      0      NaN
# 1                      7      NaN
# 2                     28      NaN
# 3                     16      NaN
# 4                     29      NaN

# %%
df.shape
# Out:
# (449, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 449 entries, 0 to 448
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              449 non-null    int64
#  1   name                            449 non-null    object
#  2   host_id                         449 non-null    int64
#  3   host_name                       449 non-null    object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   449 non-null    object
#  6   latitude                        449 non-null    float64
#  7   longitude                       449 non-null    float64
#  8   room_type                       449 non-null    object
#  9   price                           413 non-null    float64
#  10  minimum_nights                  449 non-null    int64
#  11  number_of_reviews               449 non-null    int64
#  12  last_review                     382 non-null    object
#  13  reviews_per_month               382 non-null    float64
#  14  calculated_host_listings_count  449 non-null    int64
#  15  availability_365                449 non-null    int64
#  16  number_of_reviews_ltm           449 non-null    int64
#  17  license                         0 non-null      float64
# dtypes: float64(6), int64(7), object(5)
# memory usage: 63.3+ KB

# %%
missing = df.isnull().sum()
missing = missing[missing > 0].sort_values(ascending = False)

# %%
missing
# Out:
# neighbourhood_group    449
# license                449
# last_review             67
# reviews_per_month       67
# price                   36
# dtype: int64

# %%
missing.dtypes
# Out:
# dtype('int64')

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
df = df[['id', 'name', 'host_id', 'host_name',
       'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
       'minimum_nights', 'number_of_reviews',
       'availability_365']]

# %%
df['price'] = df['price'].replace('[\$,]', '', regex=True).astype(float)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# /tmp/ipykernel_5733/2337335738.py:1: SyntaxWarning: invalid escape sequence '\$'
#   df['price'] = df['price'].replace('[\$,]', '', regex=True).astype(float)

# %%
df['price']
# Out:
# 0       70.0
# 1      102.0
# 2       75.0
# 3       96.0
# 4       88.0
#        ...
# 444     36.0
# 445     31.0
# 446    129.0
# 447     44.0
# 448     80.0
# Name: price, Length: 449, dtype: float64

# %%
df = df.dropna()

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head(2)
# Out:
#         id                                       name   host_id host_name  \
# 0  2992450                 Luxury 2 bedroom apartment   4621559   Kenneth
# 1  3820211  Restored Precinct in Center Sq. w/Parking  19648678     Terra
#
#   neighbourhood  latitude  longitude        room_type  price  minimum_nights  \
# 0    THIRD WARD  42.65789  -73.75370  Entire home/apt   70.0              28
# 1    SIXTH WARD  42.65222  -73.76724  Entire home/apt  102.0               2
#
#    number_of_reviews  availability_365
# 0                  9                32
# 1                308               334

# %% [markdown]
# ## Room Type Distribution

# %%
df['room_type'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Room Type Distribution')
plt.xlabel('Room Type')
plt.xticks(rotation = 45)
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Average Price by Room

# %%
df.groupby('room_type')['price'].mean().sort_values()
# Out:
# room_type
# Private room        63.60177
# Entire home/apt    133.17000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=df.groupby('room_type')['price'].mean().sort_values(), palette='Set2')
plt.title('Average Price by Room Type')
plt.ylabel('Average Price')
plt.show()
# Out:
# /tmp/ipykernel_5733/507208270.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df.groupby('room_type')['price'].mean().sort_values(), palette='Set2')

# %% [markdown]
# ## Price Distribution (Capped at $500)

# %%
df_price = df[df['price'] > 500]['price']
df_price
# Out:
# 26      582.0
# 130     882.0
# 133    1050.0
# 174     800.0
# 243    1200.0
# Name: price, dtype: float64

# %%
df_price.plot(kind='hist', bins=30, color = 'orange')
plt.xlabel('Price Distribution')
plt.ylabel('Frequency')
plt.title('Price Distribution (Capped at $500)')
plt.show()

# %% [markdown]
# ## Top 10 Neighbourhoods by Number of Listings

# %%
df_neighbourhood = df['neighbourhood'].value_counts().head(10)
df_neighbourhood
# Out:
# neighbourhood
# SIXTH WARD         86
# TENTH WARD         46
# SECOND WARD        45
# THIRTEENTH WARD    42
# THIRD WARD         35
# NINTH WARD         34
# FOURTEENTH WARD    25
# ELEVENTH WARD      20
# FIFTEENTH WARD     17
# SEVENTH WARD       17
# Name: count, dtype: int64

# %%
df_neighbourhood.plot(kind= 'bar', color='green')
plt.title('Top 10 Neighbourhoods by Listings')
plt.ylabel('Number of Listings')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# ## Availability vs Price

# %%
plt.scatter(df['availability_365'], df['price'],alpha= 0.4, color='green')
plt.xlabel('Availability (days/year)')
plt.ylabel('Price ($)')
plt.title('Availability vs. Price')
plt.show()

# %% [markdown]
# ## Minimum Night Distribution (Capped at 30 Nights)

# %%
df_minimum_night = df[df['minimum_nights'] < 30]['minimum_nights']
df_minimum_night
# Out:
# 0      28
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 408     2
# 409     5
# 410    28
# 411    28
# 412     3
# Name: minimum_nights, Length: 388, dtype: int64

# %%
df_minimum_night.plot(kind= 'hist', bins=30, color = 'teal')
plt.title('Minimum Night Distribution (Capped at 30 Nights)')
plt.xlabel('Minimum Nights')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Number of Reviews Distribution (Capped at 100)

# %%
df_review = df[df['number_of_reviews'] < 100]['number_of_reviews']
df_review
# Out:
# 0       9
# 9      61
# 10     28
# 12     53
# 14     48
#        ..
# 408     0
# 409     0
# 410     0
# 411     0
# 412     0
# Name: number_of_reviews, Length: 340, dtype: int64

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df_review, color='purple', bins=50)
plt.title('Number of Reviews Distribution (Capped at 100)')
plt.xlabel('Number of Review')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Correlaton Heatmap

# %%
correlation  = df[['price', 'minimum_nights', 'number_of_reviews', 'availability_365']].corr() 
correlation
# Out:
#                       price  minimum_nights  number_of_reviews  \
# price              1.000000       -0.143087          -0.068239
# minimum_nights    -0.143087        1.000000          -0.215462
# number_of_reviews -0.068239       -0.215462           1.000000
# availability_365   0.022760        0.069001          -0.042318
#
#                    availability_365
# price                      0.022760
# minimum_nights             0.069001
# number_of_reviews         -0.042318
# availability_365           1.000000

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Folium Map: Listing Locations and Prices

# %%
pip install folium
# Out:
# Requirement already satisfied: folium in /home/sabin/myenv/lib/python3.12/site-packages (0.19.7)
# Requirement already satisfied: branca>=0.6.0 in /home/sabin/myenv/lib/python3.12/site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /home/sabin/myenv/lib/python3.12/site-packages (from folium) (3.1.5)
# Requirement already satisfied: numpy in /home/sabin/myenv/lib/python3.12/site-packages (from folium) (2.0.2)
# Requirement already satisfied: requests in /home/sabin/myenv/lib/python3.12/site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /home/sabin/myenv/lib/python3.12/site-packages (from folium) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/sabin/myenv/lib/python3.12/site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sabin/myenv/lib/python3.12/site-packages (from requests->folium) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/sabin/myenv/lib/python3.12/site-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sabin/myenv/lib/python3.12/site-packages (from requests->folium) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sabin/myenv/lib/python3.12/site-packages (from requests->folium) (2025.1.31)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium

# %%
map_center = [df['latitude'].mean(), df['longitude'].mean()]
map_center
# Out:
# [np.float64(42.658458477660524), np.float64(-73.77768179477538)]

# %%
m = folium.Map(location=map_center, zoom_start=42)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e9d65d55b3b95c6d1a09ffe04767126f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e9d65d55b3b95c6d1a09ffe04767126f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e9d65d55b3b95c6d1a09ffe04767126f = L.map(
#                 &quot;map_e9d65d55b3b95c6d1a09ffe04767126f&quot;,
#                 {
#                     center: [42.658458477660524, -73.77768179477538],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 42,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0d89d2a7e0950645a3a353df99510dd4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0d89d2a7e0950645a3a353df99510dd4.addTo(map_e9d65d55b3b95c6d1a09ffe04767126f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
filterd_df = df[df['price'] < 300].sample(min(300, len(df)))
filterd_df.head(2)
# Out:
#                      id                         name    host_id host_name  \
# 217  937838302933205871  Hudson 1 at The Argus Hotel  526358730     Argus
# 47             32450400               Moroccan Sands   97330032  Sherrell
#
#      neighbourhood  latitude  longitude     room_type  price  minimum_nights  \
# 217  ELEVENTH WARD   42.6606  -73.77284  Private room  165.0               1
# 47     FOURTH WARD   42.6761  -73.73825  Private room  104.0               3
#
#      number_of_reviews  availability_365
# 217                  7               264
# 47                   1               179

# %%
for _, row in filterd_df.iterrows():
    folium.CircleMarker(
        location=[row['latitude'], row['longitude']],
        radius=3,
        color='blue',
        fill=True,
        fill_opacity=0.5,
        popup=f"${row['price']} - {row['room_type']} ({row['neighbourhood']})"
    ).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e9d65d55b3b95c6d1a09ffe04767126f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e9d65d55b3b95c6d1a09ffe04767126f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e9d65d55b3b95c6d1a09ffe04767126f = L.map(
#                 &quot;map_e9d65d55b3b95c6d1a09ffe04767126f&quot;,
#                 {
#                     center: [42.658458477660524, -73.77768179477538],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 42,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0d89d2a7e0950645a3a353df99510dd4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0d89d2a7e0950645a3a353df99510dd4.addTo(map_e9d65d55b3b95c6d1a09ffe04767126f);
#
#
#             tile_layer_0d89d2a7e0950645a3a353df99510dd4.addTo(map_e9d65d55b3b95c6d1a09ffe04767126f);
#
#
#             var circle_marker_bcbf4057e2e7409ac5d8e054d95c3494 = L.circleMarker(
#                 [42.6606, -73.77284],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e9d65d55b3b95c6d1a09ffe04767126f);
#
#
#         var popup_5af85df3c974792b84d5440d28dae03d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5c756f962d99f5a0de3f76e5d20ea57 = $(`&lt;div id=&quot;html_f5c756f962d99f5a0de3f76e5d20ea57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;$165.0 - Private room (ELEVENTH WARD)&lt;/div&gt;`)[0];
#                 popup_5af85df3c974792b84d5440d28dae03d.setContent(html_f5c756f962d99f5a0de3f76e5d20ea57);
#
#
#
#         circle_marker_bcbf4057e2e7409ac5d8e054d95c3494.bindPopup(popup_5af85df3c974792b84d5440d28dae03d)
#         ;
#
#
#
#
#             var circle_marker_9ea878e4c3f0135c8187fd9f747231e2 = L.circleMarker(
#                 [42.6761, -73.73825],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e9d65d55b3b95c6d1a09ffe04767126f);
#
#
#         var popup_23fcc776e50b5c0c0f528a6eb6c0f689 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7262fcc042111e912f91f8fa0bf7b9a7 = $(`&lt;div id=&quot;html_7262fcc042111e912f91f8fa0bf7b9a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;$104.0 - Private room (FOURTH WARD)&lt;/div&gt;`)[0];
#                 popup_23fcc776e50b5c0c0f528a6eb6c0f689.setContent(html_7262fcc042111e912f91f8fa0bf7b9a7);
#
#
#
#         circle_marker_9ea878e4c3f0135c8187fd9f747231e2.bindPopup(popup_23fcc776e50b5c0c0f528a6eb6c0f689)
#         ;
#
#
#
#
#             var circle_marker_7e6b82c3ec9bbee8c59880901936daec = L.circleMarker(
#                 [42.66045, -73.77833],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e9d65d55b3b95c6d1a09ffe04767126f);
#
#
#         var popup_4e9e0e9db53898ec8c7f6cab9825004a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_329bc03a7d7d2cafc13e61522320d513 = $(`&lt;div id=&quot;html_329bc03a7d7d2cafc13e61522320d513&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;$70.0 - Entire home/apt (TENTH WARD)&lt;/div&gt;`)[0];
#                 popup_4e9e0e9db53898ec8c7f6cab9825004a.setContent(html_329bc03a7d7d2cafc13e61522320d513);
#
#
#
#         circle_

# %%
df.to_csv("cleaned_airbnb_data.csv", index=False)

# %%
pd.read_csv(r'cleaned_airbnb_data.csv').head()
# Out:
#         id                                              name   host_id  \
# 0  2992450                        Luxury 2 bedroom apartment   4621559
# 1  3820211         Restored Precinct in Center Sq. w/Parking  19648678
# 2  5651579        Large studio apt  by Capital Center & ESP@  29288920
# 3  6623339  Center Sq. Loft in Converted Precinct w/ Parking  19648678
# 4  9005989    Studio in The heart of Center SQ, in Albany NY  17766924
#
#   host_name neighbourhood  latitude  longitude        room_type  price  \
# 0   Kenneth    THIRD WARD  42.65789  -73.75370  Entire home/apt   70.0
# 1     Terra    SIXTH WARD  42.65222  -73.76724  Entire home/apt  102.0
# 2     Gregg   SECOND WARD  42.64615  -73.75966  Entire home/apt   75.0
# 3     Terra    SIXTH WARD  42.65222  -73.76724  Entire home/apt   96.0
# 4     Sugey    SIXTH WARD  42.65559  -73.76506  Entire home/apt   88.0
#
#    minimum_nights  number_of_reviews  availability_365
# 0              28                  9                32
# 1               2                308               334
# 2               2                371                 6
# 3               2                331               305
# 4               1                617               167
